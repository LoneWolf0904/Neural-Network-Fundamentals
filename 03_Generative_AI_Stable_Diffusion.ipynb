# %% [markdown]
# # ***Task B1***

# %% [markdown]
# Task B1.1

# %% [markdown]
# Note: First install the dependencies in code cell 1 and then run the code cell 2. Also, make sure to change the runtime type to T4 GPU.

# %%
# Installing necessary dependencies

# !pip install diffusers["torch"] transformers
# !pip install accelerate
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-_zv5g25e
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-_zv5g25e
#   Resolved https://github.com/huggingface/diffusers to commit be62c85cd973f2001ab8c5d8919a9a6811fc7e43
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.33.0.dev0-py3-none-any.whl size=3251170 sha256=2563716bf4a9e242b814ea076be9015a98a5412b17c295184db5d168da3e7c96
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tqak_ult/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.32.1
#     Uninstalling diffusers-0.32.1:
#       Successfully uninstalled diffusers-0.32.1
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
from IPython.display import display

pipe = StableDiffusionPipeline.from_pretrained("Ai-user1028/wildlife-beauty", torch_dtype=torch.float16)
pipe = pipe.to("cuda")
pipe.safety_checker = None

prompt = "A cute cat face"

image = pipe(prompt).images[0]

# Resize the image to 224x224 pixels
resized_image = image.resize((224, 224))

# Display or save the resized image as needed
resized_image.show()
display(resized_image)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--Ai-user1028--wildlife-beauty/snapshots/738501a417eee92615878f282b128d4cd51bf3e5/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--Ai-user1028--wildlife-beauty/snapshots/738501a417eee92615878f282b128d4cd51bf3e5/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--Ai-user1028--wildlife-beauty/snapshots/738501a417eee92615878f282b128d4cd51bf3e5/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--Ai-user1028--wildlife-beauty/snapshots/738501a417eee92615878f282b128d4cd51bf3e5/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# ...
